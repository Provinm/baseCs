# %% [markdown]
# ## JsonPath-ng-2

# %%
from jsonpath_ng import jsonpath, parse
from jsonpath_ng.ext import parser

# %%
class FetchValue(object):
    
    SEM_TOPIC_0 = '$..SEM.._topics[0]'
    SEM_FIRST_TOPIC_NAME = ''
    def __init__(self, json_obj, *args, **kw):
        
        self.json_obj = self._pre_process(json_obj)
        self.bnf_struct = None
        self.sem_struct = None
        
    def _pre_process(self, obj):
        '''预处理 json 对象，将其转换为字典格式'''
        if isinstance(obj, dict):
            return obj
        elif isinstance(obj, str):
            dct = json.loads(obj)
            return dct
        else:
            type_obj = type(obj)
            raise ValueError, 'json_obj accepts only dict or json str, not {}'.format(type_obj)
            
    def _struct(self):
        '''解构 json_obj '''
        
        pass

# %%
dct =  {
      "BNF" : [
         {
            "_hypotheses" : [
               {
                  "_beginTimeMs" : 1128,
                  "_conf" : 5965,
                  "_endTimeMs" : 3480,
                  "_items" : [
                     {
                        "_beginTimeMs" : 1140,
                        "_conf" : 4902,
                        "_endTimeMs" : 1560,
                        "_orthography" : "拨打",
                        "_score" : 8993,
                        "_type" : "terminal"
                     },
                     {
                        "_beginTimeMs" : 1668,
                        "_conf" : 5123,
                        "_endTimeMs" : 2196,
                        "_items" : [
                           {
                              "_beginTimeMs" : 1668,
                              "_conf" : 5239,
                              "_endTimeMs" : 2196,
                              "_orthography" : "张三",
                              "_score" : 9297,
                              "_type" : "terminal",
                              "_userID.hi32" : 0,
                              "_userID.lo32" : 31
                           }
                        ],
                        "_name" : "NGX_MNC_BNF#CONTACT_NAME",
                        "_score" : 9297,
                        "_type" : "tag"
                     },
                     {
                        "_beginTimeMs" : 2220,
                        "_conf" : 6190,
                        "_endTimeMs" : 2352,
                        "_orthography" : "的",
                        "_score" : 2489,
                        "_type" : "terminal"
                     },
                     {
                        "_beginTimeMs" : 2352,
                        "_conf" : 7878,
                        "_endTimeMs" : 2952,
                        "_orthography" : "电话",
                        "_score" : 9884,
                        "_type" : "terminal"
                     }
                  ],
                  "_lmScore" : 160,
                  "_score" : 39824,
                  "_startRule" : "NGX_MNC_BNF#START_OF_NGX_MNC_BNF"
               },
               {
                  "_beginTimeMs" : 1128,
                  "_conf" : 5965,
                  "_endTimeMs" : 3480,
                  "_items" : [
                     {
                        "_beginTimeMs" : 1140,
                        "_conf" : 4902,
                        "_endTimeMs" : 1560,
                        "_orthography" : "拨打",
                        "_score" : 8993,
                        "_type" : "terminal"
                     },
                     {
                        "_beginTimeMs" : 1668,
                        "_conf" : 5123,
                        "_endTimeMs" : 2196,
                        "_items" : [
                           {
                              "_beginTimeMs" : 1668,
                              "_conf" : 5239,
                              "_endTimeMs" : 2196,
                              "_orthography" : "章三",
                              "_score" : 9297,
                              "_type" : "terminal",
                              "_userID.hi32" : 0,
                              "_userID.lo32" : 32
                           }
                        ],
                        "_name" : "NGX_MNC_BNF#CONTACT_NAME",
                        "_score" : 9297,
                        "_type" : "tag"
                     },
                     {
                        "_beginTimeMs" : 2220,
                        "_conf" : 6190,
                        "_endTimeMs" : 2352,
                        "_orthography" : "的",
                        "_score" : 2489,
                        "_type" : "terminal"
                     },
                     {
                        "_beginTimeMs" : 2352,
                        "_conf" : 7878,
                        "_endTimeMs" : 2952,
                        "_orthography" : "电话",
                        "_score" : 9884,
                        "_type" : "terminal"
                     }
                  ],
                  "_lmScore" : 160,
                  "_score" : 39824,
                  "_startRule" : "NGX_MNC_BNF#START_OF_NGX_MNC_BNF"
               },
               {
                  "_beginTimeMs" : 1128,
                  "_conf" : 5965,
                  "_endTimeMs" : 3480,
                  "_items" : [
                     {
                        "_beginTimeMs" : 1140,
                        "_conf" : 4902,
                        "_endTimeMs" : 1560,
                        "_orthography" : "拨打",
                        "_score" : 8993,
                        "_type" : "terminal"
                     },
                     {
                        "_beginTimeMs" : 1668,
                        "_conf" : 5123,
                        "_endTimeMs" : 2196,
                        "_items" : [
                           {
                              "_beginTimeMs" : 1668,
                              "_conf" : 5239,
                              "_endTimeMs" : 2196,
                              "_orthography" : "张三",
                              "_score" : 9297,
                              "_type" : "terminal",
                              "_userID.hi32" : 0,
                              "_userID.lo32" : 0
                           }
                        ],
                        "_name" : "NGX_MNC_BNF#CONTACT_NAME",
                        "_score" : 9297,
                        "_type" : "tag"
                     },
                     {
                        "_beginTimeMs" : 2220,
                        "_conf" : 6190,
                        "_endTimeMs" : 2352,
                        "_orthography" : "的",
                        "_score" : 2489,
                        "_type" : "terminal"
                     },
                     {
                        "_beginTimeMs" : 2352,
                        "_conf" : 7878,
                        "_endTimeMs" : 2952,
                        "_orthography" : "电话",
                        "_score" : 9884,
                        "_type" : "terminal"
                     }
                  ],
                  "_lmScore" : 160,
                  "_score" : 39824,
                  "_startRule" : "NGX_MNC_BNF#START_OF_NGX_MNC_BNF"
               },
               {
                  "_beginTimeMs" : 1128,
                  "_conf" : 5580,
                  "_endTimeMs" : 3480,
                  "_items" : [
                     {
                        "_beginTimeMs" : 1140,
                        "_conf" : 4902,
                        "_endTimeMs" : 1560,
                        "_orthography" : "拨打",
                        "_score" : 8993,
                        "_type" : "terminal"
                     },
                     {
                        "_beginTimeMs" : 1668,
                        "_conf" : 4696,
                        "_endTimeMs" : 2196,
                        "_items" : [
                           {
                              "_beginTimeMs" : 1668,
                              "_conf" : 5239,
                              "_endTimeMs" : 2196,
                              "_orthography" : "张三",
                              "_score" : 9297,
                              "_type" : "terminal",
                              "_userID.hi32" : 0,
                              "_userID.lo32" : 31
                           }
                        ],
                        "_name" : "NGX_MNC_BNF#CONTACT_NAME",
                        "_score" : 9297,
                        "_type" : "tag"
                     },
                     {
                        "_beginTimeMs" : 2400,
                        "_conf" : 7618,
                        "_endTimeMs" : 2952,
                        "_orthography" : "电话",
                        "_score" : 9133,
                        "_type" : "terminal"
                     }
                  ],
                  "_lmScore" : 120,
                  "_score" : 40529,
                  "_startRule" : "NGX_MNC_BNF#START_OF_NGX_MNC_BNF"
               },
               {
                  "_beginTimeMs" : 1128,
                  "_conf" : 5580,
                  "_endTimeMs" : 3480,
                  "_items" : [
                     {
                        "_beginTimeMs" : 1140,
                        "_conf" : 4902,
                        "_endTimeMs" : 1560,
                        "_orthography" : "拨打",
                        "_score" : 8993,
                        "_type" : "terminal"
                     },
                     {
                        "_beginTimeMs" : 1668,
                        "_conf" : 4696,
                        "_endTimeMs" : 2196,
                        "_items" : [
                           {
                              "_beginTimeMs" : 1668,
                              "_conf" : 5239,
                              "_endTimeMs" : 2196,
                              "_orthography" : "章三",
                              "_score" : 9297,
                              "_type" : "terminal",
                              "_userID.hi32" : 0,
                              "_userID.lo32" : 32
                           }
                        ],
                        "_name" : "NGX_MNC_BNF#CONTACT_NAME",
                        "_score" : 9297,
                        "_type" : "tag"
                     },
                     {
                        "_beginTimeMs" : 2400,
                        "_conf" : 7618,
                        "_endTimeMs" : 2952,
                        "_orthography" : "电话",
                        "_score" : 9133,
                        "_type" : "terminal"
                     }
                  ],
                  "_lmScore" : 120,
                  "_score" : 40529,
                  "_startRule" : "NGX_MNC_BNF#START_OF_NGX_MNC_BNF"
               }
            ],
            "_isInGrammar" : "yes",
            "_isSpeech" : "yes",
            "_resultType" : "NBest"
         },
         {
            "_hypotheses" : [
               {
                  "_beginTimeMs" : 1128,
                  "_conf" : 5965,
                  "_endTimeMs" : 3480,
                  "_items" : [
                     {
                        "_beginTimeMs" : 1140,
                        "_conf" : 4902,
                        "_endTimeMs" : 1560,
                        "_orthography" : "拨打",
                        "_score" : 8993,
                        "_type" : "terminal"
                     },
                     {
                        "_beginTimeMs" : 1668,
                        "_conf" : 5123,
                        "_endTimeMs" : 2196,
                        "_items" : [
                           {
                              "_beginTimeMs" : 1668,
                              "_conf" : 5239,
                              "_endTimeMs" : 2196,
                              "_orthography" : "章三",
                              "_score" : 9297,
                              "_type" : "terminal",
                              "_userID.hi32" : 0,
                              "_userID.lo32" : 32
                           }
                        ],
                        "_name" : "NGX_MNC_SLM#CONTACT_NAME",
                        "_score" : 9297,
                        "_type" : "tag"
                     },
                     {
                        "_beginTimeMs" : 2220,
                        "_conf" : 6190,
                        "_endTimeMs" : 2352,
                        "_orthography" : "的",
                        "_score" : 2489,
                        "_type" : "terminal"
                     },
                     {
                        "_beginTimeMs" : 2352,
                        "_conf" : 7878,
                        "_endTimeMs" : 2952,
                        "_orthography" : "电话",
                        "_score" : 9884,
                        "_type" : "terminal"
                     }
                  ],
                  "_lmScore" : 641,
                  "_score" : 39824,
                  "_startRule" : "NGX_MNC_SLM#START"
               },
               {
                  "_beginTimeMs" : 1128,
                  "_conf" : 5965,
                  "_endTimeMs" : 3480,
                  "_items" : [
                     {
                        "_beginTimeMs" : 1140,
                        "_conf" : 4902,
                        "_endTimeMs" : 1560,
                        "_orthography" : "拨打",
                        "_score" : 8993,
                        "_type" : "terminal"
                     },
                     {
                        "_beginTimeMs" : 1668,
                        "_conf" : 5123,
                        "_endTimeMs" : 2196,
                        "_items" : [
                           {
                              "_beginTimeMs" : 1668,
                              "_conf" : 5239,
                              "_endTimeMs" : 2196,
                              "_orthography" : "张三",
                              "_score" : 9297,
                              "_type" : "terminal",
                              "_userID.hi32" : 0,
                              "_userID.lo32" : 0
                           }
                        ],
                        "_name" : "NGX_MNC_SLM#CONTACT_NAME",
                        "_score" : 9297,
                        "_type" : "tag"
                     },
                     {
                        "_beginTimeMs" : 2220,
                        "_conf" : 6190,
                        "_endTimeMs" : 2352,
                        "_orthography" : "的",
                        "_score" : 2489,
                        "_type" : "terminal"
                     },
                     {
                        "_beginTimeMs" : 2352,
                        "_conf" : 7878,
                        "_endTimeMs" : 2952,
                        "_orthography" : "电话",
                        "_score" : 9884,
                        "_type" : "terminal"
                     }
                  ],
                  "_lmScore" : 641,
                  "_score" : 39824,
                  "_startRule" : "NGX_MNC_SLM#START"
               },
               {
                  "_beginTimeMs" : 1128,
                  "_conf" : 5965,
                  "_endTimeMs" : 3480,
                  "_items" : [
                     {
                        "_beginTimeMs" : 1140,
                        "_conf" : 4902,
                        "_endTimeMs" : 1560,
                        "_orthography" : "拨打",
                        "_score" : 8993,
                        "_type" : "terminal"
                     },
                     {
                        "_beginTimeMs" : 1668,
                        "_conf" : 5123,
                        "_endTimeMs" : 2196,
                        "_items" : [
                           {
                              "_beginTimeMs" : 1668,
                              "_conf" : 5239,
                              "_endTimeMs" : 2196,
                              "_orthography" : "张三",
                              "_score" : 9297,
                              "_type" : "terminal",
                              "_userID.hi32" : 0,
                              "_userID.lo32" : 31
                           }
                        ],
                        "_name" : "NGX_MNC_SLM#CONTACT_NAME",
                        "_score" : 9297,
                        "_type" : "tag"
                     },
                     {
                        "_beginTimeMs" : 2220,
                        "_conf" : 6190,
                        "_endTimeMs" : 2352,
                        "_orthography" : "的",
                        "_score" : 2489,
                        "_type" : "terminal"
                     },
                     {
                        "_beginTimeMs" : 2352,
                        "_conf" : 7878,
                        "_endTimeMs" : 2952,
                        "_orthography" : "电话",
                        "_score" : 9884,
                        "_type" : "terminal"
                     }
                  ],
                  "_lmScore" : 641,
                  "_score" : 39824,
                  "_startRule" : "NGX_MNC_SLM#START"
               }
            ],
            "_isInGrammar" : "yes",
            "_isSpeech" : "yes",
            "_resultType" : "NBest"
         }
      ],
      "SEM" : {
         "_resultType" : "Sem",
         "_topics" : [
            {
               "_interpretations" : [
                  {
                     "_score" : 5965,
                     "_slots" : [
                        {
                           "_items" : [
                              {
                                 "_beginTimeMs" : 1668,
                                 "_conf" : 5239,
                                 "_endTimeMs" : 2196,
                                 "_orthography" : "张三",
                                 "_type" : "terminal",
                                 "_userID.hi32" : 0,
                                 "_userID.lo32" : 31
                              }
                           ],
                           "_name" : "CONTACT_NAME",
                           "_value" : "张三"
                        },
                        {
                           "_items" : [],
                           "_name" : "PHONE_TYPE",
                           "_value" : ""
                        },
                        {
                           "_items" : [],
                           "_name" : "NUM_FEATURE",
                           "_value" : ""
                        },
                        {
                           "_items" : [],
                           "_name" : "DIAL_DEVICE",
                           "_value" : ""
                        }
                     ]
                  },
                  {
                     "_score" : 5965,
                     "_slots" : [
                        {
                           "_items" : [
                              {
                                 "_beginTimeMs" : 1668,
                                 "_conf" : 5239,
                                 "_endTimeMs" : 2196,
                                 "_orthography" : "章三",
                                 "_type" : "terminal",
                                 "_userID.hi32" : 0,
                                 "_userID.lo32" : 32
                              }
                           ],
                           "_name" : "CONTACT_NAME",
                           "_value" : "章三"
                        },
                        {
                           "_items" : [],
                           "_name" : "PHONE_TYPE",
                           "_value" : ""
                        },
                        {
                           "_items" : [],
                           "_name" : "NUM_FEATURE",
                           "_value" : ""
                        },
                        {
                           "_items" : [],
                           "_name" : "DIAL_DEVICE",
                           "_value" : ""
                        }
                     ]
                  },
                  {
                     "_score" : 5965,
                     "_slots" : [
                        {
                           "_items" : [
                              {
                                 "_beginTimeMs" : 1668,
                                 "_conf" : 5239,
                                 "_endTimeMs" : 2196,
                                 "_orthography" : "张三",
                                 "_type" : "terminal",
                                 "_userID.hi32" : 0,
                                 "_userID.lo32" : 0
                              }
                           ],
                           "_name" : "CONTACT_NAME",
                           "_value" : "张三"
                        },
                        {
                           "_items" : [],
                           "_name" : "PHONE_TYPE",
                           "_value" : ""
                        },
                        {
                           "_items" : [],
                           "_name" : "NUM_FEATURE",
                           "_value" : ""
                        },
                        {
                           "_items" : [],
                           "_name" : "DIAL_DEVICE",
                           "_value" : ""
                        }
                     ]
                  }
               ],
               "_name" : "Phn_CallNameWithType",
               "_score" : 5965
            },
            {
               "_interpretations" : [
                  {
                     "_score" : 5965,
                     "_slots" : [
                        {
                           "_items" : [],
                           "_name" : "PHONE_NUMBER",
                           "_value" : ""
                        },
                        {
                           "_items" : [],
                           "_name" : "DIAL_DEVICE",
                           "_value" : ""
                        }
                     ]
                  }
               ],
               "_name" : "Phn_CallNumber",
               "_score" : 15
            },
            {
               "_interpretations" : [
                  {
                     "_score" : 5965,
                     "_slots" : [
                        {
                           "_items" : [
                              {
                                 "_beginTimeMs" : 1668,
                                 "_conf" : 5239,
                                 "_endTimeMs" : 2196,
                                 "_orthography" : "张三",
                                 "_type" : "terminal",
                                 "_userID.hi32" : 0,
                                 "_userID.lo32" : 31
                              }
                           ],
                           "_name" : "CONTACT_NAME",
                           "_value" : "张三"
                        }
                     ]
                  },
                  {
                     "_score" : 5965,
                     "_slots" : [
                        {
                           "_items" : [
                              {
                                 "_beginTimeMs" : 1668,
                                 "_conf" : 5239,
                                 "_endTimeMs" : 2196,
                                 "_orthography" : "章三",
                                 "_type" : "terminal",
                                 "_userID.hi32" : 0,
                                 "_userID.lo32" : 32
                              }
                           ],
                           "_name" : "CONTACT_NAME",
                           "_value" : "章三"
                        }
                     ]
                  },
                  {
                     "_score" : 5965,
                     "_slots" : [
                        {
                           "_items" : [
                              {
                                 "_beginTimeMs" : 1668,
                                 "_conf" : 5239,
                                 "_endTimeMs" : 2196,
                                 "_orthography" : "张三",
                                 "_type" : "terminal",
                                 "_userID.hi32" : 0,
                                 "_userID.lo32" : 0
                              }
                           ],
                           "_name" : "CONTACT_NAME",
                           "_value" : "张三"
                        }
                     ]
                  }
               ],
               "_name" : "SMS_ReadByName",
               "_score" : 14
            }
         ]
      }
   }

# %%
type(dct)
# Out:
# dict

# %%
dct2 = {'objects': [
    {'cow': 2, 'cat': 3},
    {'cow': 4, 'cat': 6},
    {'cow': 4, 'cat': 6, 'coat': 8, 's':10},
]}

# %%
pattern = parser.parse('$.objects[0]')
r = pattern.find(dct2)
r
# Out:
# [DatumInContext(value={'cow': 2, 'cat': 3}, path=<jsonpath_ng.jsonpath.Index object at 0x06463E90>, context=DatumInContext(value=[{'cow': 2, 'cat': 3}, {'cow': 4, 'cat': 6}, {'coat': 8, 's': 10, 'cow': 4, 'cat': 6}], path=Fields('objects'), context=DatumInContext(value={'objects': [{'cow': 2, 'cat': 3}, {'cow': 4, 'cat': 6}, {'coat': 8, 's': 10, 'cow': 4, 'cat': 6}]}, path=Root(), context=None)))]

# %%
len(r)
# Out:
# 1

# %%
type(dct2)
# Out:
# dict

# %%
pattern = parse('$..cow')

# %%
[i.context.value for i in pattern.find(dct2)]
# Out:
# [{'cat': 3, 'cow': 2}, {'cat': 6, 'cow': 4}]

# %%
pattern = parser.parse('$.objects[?coat].cow')

# %%
[i.context.value for i in pattern.find(dct2)]
# Out:
# [{'cat': 6, 'coat': 8, 'cow': 4, 's': 10}]

# %%
pattern = parser.parse('$.._hypotheses[*]')
r = pattern.find(dct)

# %%
len(r)
# Out:
# 8

# %%
r[0].value
# Out:
# {'_beginTimeMs': 1128,
#  '_conf': 5965,
#  '_endTimeMs': 3480,
#  '_items': [{'_beginTimeMs': 1140,
#    '_conf': 4902,
#    '_endTimeMs': 1560,
#    '_orthography': '\xe6\x8b\xa8\xe6\x89\x93',
#    '_score': 8993,
#    '_type': 'terminal'},
#   {'_beginTimeMs': 1668,
#    '_conf': 5123,
#    '_endTimeMs': 2196,
#    '_items': [{'_beginTimeMs': 1668,
#      '_conf': 5239,
#      '_endTimeMs': 2196,
#      '_orthography': '\xe5\xbc\xa0\xe4\xb8\x89',
#      '_score': 9297,
#      '_type': 'terminal',
#      '_userID.hi32': 0,
#      '_userID.lo32': 31}],
#    '_name': 'NGX_MNC_BNF#CONTACT_NAME',
#    '_score': 9297,
#    '_type': 'tag'},
#   {'_beginTimeMs': 2220,
#    '_conf': 6190,
#    '_endTimeMs': 2352,
#    '_orthography': '\xe7\x9a\x84',
#    '_score': 2489,
#    '_type': 'terminal'},
#   {'_beginTimeMs': 2352,
#    '_conf': 7878,
#    '_endTimeMs': 2952,
#    '_orthography': '\xe7\x94\xb5\xe8\xaf\x9d',
#    '_score': 9884,
#    '_type': 'terminal'}],
#  '_lmScore': 160,
# ...

# %%
BNF_TOPIC_POINT = parser.parse('$..BNF.._hypotheses[*].._items[?_type="tag"]._name')

# %%
r = BNF_TOPIC_POINT.find(dct)

# %%
len(r)
# Out:
# 8

# %%
[i.context.value for i in r]
# Out:
# [{'_beginTimeMs': 1668,
#   '_conf': 5123,
#   '_endTimeMs': 2196,
#   '_items': [{'_beginTimeMs': 1668,
#     '_conf': 5239,
#     '_endTimeMs': 2196,
#     '_orthography': '\xe5\xbc\xa0\xe4\xb8\x89',
#     '_score': 9297,
#     '_type': 'terminal',
#     '_userID.hi32': 0,
#     '_userID.lo32': 31}],
#   '_name': 'NGX_MNC_BNF#CONTACT_NAME',
#   '_score': 9297,
#   '_type': 'tag'},
#  {'_beginTimeMs': 1668,
#   '_conf': 5123,
#   '_endTimeMs': 2196,
#   '_items': [{'_beginTimeMs': 1668,
#     '_conf': 5239,
#     '_endTimeMs': 2196,
#     '_orthography': '\xe7\xab\xa0\xe4\xb8\x89',
#     '_score': 9297,
#     '_type': 'terminal',
#     '_userID.hi32': 0,
#     '_userID.lo32': 32}],
#   '_name': 'NGX_MNC_BNF#CONTACT_NAME',
#   '_score': 9297,
#   '_type': 'tag'},
#  {'_beginTimeMs': 1668,
#   '_conf': 5123,
#   '_endTimeMs': 2196,
#   '_items': [{'_beginTimeMs': 1668,
#     '_conf': 5239,
#     '_endTimeMs': 2196,
#     '_orthography': '\xe5\xbc\xa0\xe4\xb8\x89',
# ...

# %%
from collections import defaultdict
from collections import OrderedDict
d = defaultdict(list)

# %%
d['s']
# Out:
# []

# %%
inter1 = {
               "_interpretations" : [
                  {
                     "_score" : 6748,
                     "_slots" : [
                        {
                           "_items" : [
                              {
                                 "_beginTimeMs" : 408,
                                 "_conf" : 7805,
                                 "_endTimeMs" : 924,
                                 "_orthography" : "明天",
                                 "_type" : "terminal",
                                 "_userID.hi32" : 0,
                                 "_userID.lo32" : 302
                              },
                              {
                                 "_beginTimeMs" : 924,
                                 "_conf" : 7070,
                                 "_endTimeMs" : 1488,
                                 "_orthography" : "早上",
                                 "_type" : "terminal",
                                 "_userID.hi32" : 0,
                                 "_userID.lo32" : 401
                              },
                              {
                                 "_beginTimeMs" : 1488,
                                 "_conf" : 5330,
                                 "_endTimeMs" : 1716,
                                 "_orthography" : "8",
                                 "_type" : "terminal",
                                 "_userID.hi32" : 0,
                                 "_userID.lo32" : 8
                              },
                              {
                                 "_beginTimeMs" : 1716,
                                 "_conf" : 7113,
                                 "_endTimeMs" : 1968,
                                 "_orthography" : "点",
                                 "_type" : "terminal",
                                 "_userID.hi32" : 0,
                                 "_userID.lo32" : 800
                              }
                           ],
                           "_name" : "TIME_EVENT",
                           "_value" : "明天 早上 8 点"
                        }
                     ]
                  },
                  {
                     "_score" : 6488,
                     "_slots" : [
                        {
                           "_items" : [
                              {
                                 "_beginTimeMs" : 408,
                                 "_conf" : 7805,
                                 "_endTimeMs" : 924,
                                 "_orthography" : "明天",
                                 "_type" : "terminal",
                                 "_userID.hi32" : 0,
                                 "_userID.lo32" : 302
                              },
                              {
                                 "_beginTimeMs" : 924,
                                 "_conf" : 6580,
                                 "_endTimeMs" : 1452,
                                 "_orthography" : "早上",
                                 "_type" : "terminal",
                                 "_userID.hi32" : 0,
                                 "_userID.lo32" : 401
                              },
                              {
                                 "_beginTimeMs" : 1488,
                                 "_conf" : 3845,
                                 "_endTimeMs" : 1740,
                                 "_orthography" : "2",
                                 "_type" : "terminal",
                                 "_userID.hi32" : 0,
                                 "_userID.lo32" : 2
                              },
                              {
                                 "_beginTimeMs" : 1740,
                                 "_conf" : 7229,
                                 "_endTimeMs" : 1968,
                                 "_orthography" : "点",
                                 "_type" : "terminal",
                                 "_userID.hi32" : 0,
                                 "_userID.lo32" : 800
                              }
                           ],
                           "_name" : "TIME_EVENT",
                           "_value" : "明天 早上 2 点"
                        }
                     ]
                  },
                  {
                     "_score" : 6402,
                     "_slots" : [
                        {
                           "_items" : [
                              {
                                 "_beginTimeMs" : 408,
                                 "_conf" : 7805,
                                 "_endTimeMs" : 924,
                                 "_orthography" : "明天",
                                 "_type" : "terminal",
                                 "_userID.hi32" : 0,
                                 "_userID.lo32" : 302
                              },
                              {
                                 "_beginTimeMs" : 924,
                                 "_conf" : 6690,
                                 "_endTimeMs" : 1392,
                                 "_orthography" : "早上",
                                 "_type" : "terminal",
                                 "_userID.hi32" : 0,
                                 "_userID.lo32" : 401
                              },
                              {
                                 "_beginTimeMs" : 1392,
                                 "_conf" : 167,
                                 "_endTimeMs" : 1488,
                                 "_orthography" : "十",
                                 "_type" : "terminal",
                                 "_userID.hi32" : 0,
                                 "_userID.lo32" : 10
                              },
                              {
                                 "_beginTimeMs" : 1488,
                                 "_conf" : 5431,
                                 "_endTimeMs" : 1716,
                                 "_orthography" : "8",
                                 "_type" : "terminal",
                                 "_userID.hi32" : 0,
                                 "_userID.lo32" : 8
                              },
                              {
                                 "_beginTimeMs" : 1716,
                                 "_conf" : 7113,
                                 "_endTimeMs" : 1968,
                                 "_orthography" : "点",
                                 "_type" : "terminal",
                                 "_userID.hi32" : 0,
                                 "_userID.lo32" : 800
                              }
                           ],
                           "_name" : "TIME_EVENT",
                           "_value" : "明天 早上 十 8 点"
                        }
                     ]
                  }
               ],
               "_name" : "Reminder_Add",
               "_score" : 6748
            }

# %%
pattern1 = parser.parse('$.._slots[*]')
r = pattern1.find(inter1)
len(r)
# Out:
# 3

# %%
rr = r[0].value

# %%
r[1].value
# Out:
# '\xe6\x98\x8e\xe5\xa4\xa9 \xe6\x97\xa9\xe4\xb8\x8a 8 \xe7\x82\xb9'

# %%
type(rr)
# Out:
# dict

# %%
rr
# Out:
# {'_items': [{'_beginTimeMs': 408,
#    '_conf': 7805,
#    '_endTimeMs': 924,
#    '_orthography': '\xe6\x98\x8e\xe5\xa4\xa9',
#    '_type': 'terminal',
#    '_userID.hi32': 0,
#    '_userID.lo32': 302},
#   {'_beginTimeMs': 924,
#    '_conf': 7070,
#    '_endTimeMs': 1488,
#    '_orthography': '\xe6\x97\xa9\xe4\xb8\x8a',
#    '_type': 'terminal',
#    '_userID.hi32': 0,
#    '_userID.lo32': 401},
#   {'_beginTimeMs': 1488,
#    '_conf': 5330,
#    '_endTimeMs': 1716,
#    '_orthography': '8',
#    '_type': 'terminal',
#    '_userID.hi32': 0,
#    '_userID.lo32': 8},
#   {'_beginTimeMs': 1716,
#    '_conf': 7113,
#    '_endTimeMs': 1968,
#    '_orthography': '\xe7\x82\xb9',
#    '_type': 'terminal',
#    '_userID.hi32': 0,
#    '_userID.lo32': 800}],
#  '_name': 'TIME_EVENT',
#  '_value': '\xe6\x98\x8e\xe5\xa4\xa9 \xe6\x97\xa9\xe4\xb8\x8a 8 \xe7\x82\xb9'}

# %%
SEM_SLOT_ITEMS = parser.parse('$..[_orthography,_conf,"_userID.hi32","_userID.lo32"]')

# %%
r = SEM_SLOT_ITEMS.find(rr)

# %%
len(r)
# Out:
# 16

# %%
[i.value for i in r]
# Out:
# ['\xe6\x98\x8e\xe5\xa4\xa9',
#  7805,
#  0,
#  302,
#  '\xe6\x97\xa9\xe4\xb8\x8a',
#  7070,
#  0,
#  401,
#  '8',
#  5330,
#  0,
#  8,
#  '\xe7\x82\xb9',
#  7113,
#  0,
#  800]
